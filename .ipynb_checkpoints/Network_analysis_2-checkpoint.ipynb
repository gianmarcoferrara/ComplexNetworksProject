# %%
import os
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Path to the directory where the files are stored
directory = "/Users/gianmarcoferrara/Desktop/2_adjacency_matrices/"  

# Step 1: Load the networks
network_list = []
for i in range(1, 33):  # 32 networks
    file_path = os.path.join(directory, f"2_adjacency_matrix_{i}.csv")
    try:
        # Load the adjacency matrix
        matrix = pd.read_csv(file_path, delimiter=',', header=None).values
        matrix = np.nan_to_num(matrix)  # Replace NaNs with 0
        G = nx.from_numpy_array(matrix)  # Create the graph
        network_list.append(G)  # Add to the list of networks
    except Exception as e:
        print(f"Error loading file {file_path}: {e}")

# Step 2: Lists for key parameters
densities = []
average_degrees = []
clustering_coefficients = []

# Step 3: Iterate and calculate parameters for each network
for i, G in enumerate(network_list, start=1):
    try:
        # Calculate parameters
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()
        density = nx.density(G)
        avg_degree = sum(dict(G.degree()).values()) / num_nodes if num_nodes > 0 else 0
        avg_clustering = nx.average_clustering(G)
        
        # Save the results
        densities.append(density)
        average_degrees.append(avg_degree)
        clustering_coefficients.append(avg_clustering)
        
        # Print parameters for each network
        print(f"Network {i}:")
        print(f"  Number of nodes: {num_nodes}")
        print(f"  Number of edges: {num_edges}")
        print(f"  Density: {density}")
        print(f"  Average degree: {avg_degree}")
        print(f"  Average clustering coefficient: {avg_clustering}\n")
        
    except Exception as e:
        print(f"Error with network {i}: {e}")
        continue

# Step 4: Calculate and print the average values of each parameter across all networks
average_density = np.mean(densities)
average_degree = np.mean(average_degrees)
average_clustering = np.mean(clustering_coefficients)

print("\nAverage values across all networks:")
print(f"  Average Density: {average_density}")
print(f"  Average Degree: {average_degree}")
print(f"  Average Clustering Coefficient: {average_clustering}")

# Step 5: Visualize the parameters
plt.figure(figsize=(14, 8))

# Density
plt.subplot(2, 2, 1)
plt.plot(range(1, len(network_list) + 1), densities, marker='o', color='b')
plt.title("Network Density")
plt.xlabel("Network")
plt.ylabel("Density")
plt.grid(True)

# Average degree
plt.subplot(2, 2, 2)
plt.plot(range(1, len(network_list) + 1), average_degrees, marker='o', color='g')
plt.title("Average Degree")
plt.xlabel("Network")
plt.ylabel("Average Degree")
plt.grid(True)

# Clustering coefficient
plt.subplot(2, 2, 3)
plt.plot(range(1, len(network_list) + 1), clustering_coefficients, marker='o', color='r')
plt.title("Average Clustering Coefficient")
plt.xlabel("Network")
plt.ylabel("Clustering Coefficient")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Network 1:
#   Number of nodes: 3105
#   Number of edges: 43307
#   Density: 0.008986793831034082
#   Average degree: 27.89500805152979
#   Average clustering coefficient: 0.36343546644161284
#
# Network 2:
#   Number of nodes: 3105
#   Number of edges: 48050
#   Density: 0.009971031093845974
#   Average degree: 30.950080515297905
#   Average clustering coefficient: 0.35564150780433035
#
# Network 3:
#   Number of nodes: 3105
#   Number of edges: 12179
#   Density: 0.002527308796918837
#   Average degree: 7.844766505636071
#   Average clustering coefficient: 0.2508073546460119
#
# Network 4:
#   Number of nodes: 3105
#   Number of edges: 16723
#   Density: 0.0034702508425054368
#   Average degree: 10.771658615136875
#   Average clustering coefficient: 0.25006762663568965
#
# Network 5:
#   Number of nodes: 3105
#   Number of edges: 87362
#   Density: 0.018128807875558213
#   Average degree: 56.27181964573269
#   Average clustering coefficient: 0.4126279665227232
#
# Network 6:
#   Number of nodes: 3105
#   Number of edges: 184204
#   Density: 0.03822484519481382
#   Average degree: 118.6499194847021
#   Average clustering coefficient: 0.5416721471347823
#
# Network 7:
#   Number of nodes: 3105
#   Number of edges: 49672
#   Density: 0.010307618241280276
#   Average degree: 31.994847020933978
#   Average clustering coefficient: 0.4612892789564159
#
# Network 8:
#   Number of nodes: 3105
#   Number of edges: 22269
#   Density: 0.0046211215697992926
#   Average degree: 14.343961352657004
#   Average clustering coefficient: 0.4152797595811485
#
# Network 9:
#   Number of nodes: 3105
#   Number of edges: 35792
#   Density: 0.007427328718229659
#   Average degree: 23.054428341384863
#   Average clustering coefficient: 0.47476138715123156
#
# Network 10:
#   Number of nodes: 3105
#   Number of edges: 86438
#   Density: 0.017937065258894037
#   Average degree: 55.67665056360708
#   Average clustering coefficient: 0.4978067927721632
#
# Network 11:
#   Number of nodes: 3105
#   Number of edges: 91334
#   Density: 0.018953052110828893
#   Average degree: 58.830273752012886
#   Average clustering coefficient: 0.47698242567508997
#
# Network 12:
#   Number of nodes: 3105
#   Number of edges: 37719
#   Density: 0.007827207530255492
#   Average degree: 24.295652173913044
#   Average clustering coefficient: 0.3517063067354684
#
# Network 13:
#   Number of nodes: 3105
#   Number of edges: 80510
#   Density: 0.01670692431561997
#   Average degree: 51.85829307568438
#   Average clustering coefficient: 0.4242582602223452
#
# Network 14:
#   Number of nodes: 3105
#   Number of edges: 185846
#   Density: 0.03856558261533609
#   Average degree: 119.70756843800322
#   Average clustering coefficient: 0.5740038824357699
#
# Network 15:
#   Number of nodes: 3105
#   Number of edges: 616515
#   Density: 0.1279352806414662
#   Average degree: 397.1111111111111
#   Average clustering coefficient: 0.6778708715293096
#
# Network 16:
#   Number of nodes: 3105
#   Number of edges: 517169
#   Density: 0.10731962913159686
#   Average degree: 333.12012882447664
#   Average clustering coefficient: 0.6708632987112143
#
# Network 17:
#   Number of nodes: 3105
#   Number of edges: 256545
#   Density: 0.05323659046765277
#   Average degree: 165.2463768115942
#   Average clustering coefficient: 0.609678744519569
#
# Network 18:
#   Number of nodes: 3105
#   Number of edges: 182673
#   Density: 0.03790714178992978
#   Average degree: 117.66376811594203
#   Average clustering coefficient: 0.602694033354721
#
# Network 19:
#   Number of nodes: 3105
#   Number of edges: 191193
#   Density: 0.039675158125404654
#   Average degree: 123.15169082125604
#   Average clustering coefficient: 0.6146168567010357
#
# Network 20:
#   Number of nodes: 3105
#   Number of edges: 501540
#   Density: 0.10407639822700333
#   Average degree: 323.05314009661834
#   Average clustering coefficient: 0.6451152444891609
#
# Network 21:
#   Number of nodes: 3105
#   Number of edges: 474076
#   Density: 0.09837724322260405
#   Average degree: 305.36296296296297
#   Average clustering coefficient: 0.6588315954318097
#
# Network 22:
#   Number of nodes: 3105
#   Number of edges: 653608
#   Density: 0.13563258462406827
#   Average degree: 421.0035426731079
#   Average clustering coefficient: 0.6635167392488118
#
# Network 23:
#   Number of nodes: 3105
#   Number of edges: 875957
#   Density: 0.1817730381659113
#   Average degree: 564.2235104669887
#   Average clustering coefficient: 0.6718544874523101
#
# Network 24:
#   Number of nodes: 3105
#   Number of edges: 230224
#   Density: 0.04777462357023092
#   Average degree: 148.29243156199678
#   Average clustering coefficient: 0.6315524403083177
#
# Network 25:
#   Number of nodes: 3105
#   Number of edges: 534479
#   Density: 0.11091169048923419
#   Average degree: 344.2698872785829
#   Average clustering coefficient: 0.6823841117676422
#
# Network 26:
#   Number of nodes: 3105
#   Number of edges: 750724
#   Density: 0.15578548068462905
#   Average degree: 483.55813204508854
#   Average clustering coefficient: 0.736656288607004
#
# Network 27:
#   Number of nodes: 3105
#   Number of edges: 930036
#   Density: 0.1929951690821256
#   Average degree: 599.0570048309179
#   Average clustering coefficient: 0.7567551978324747
#
# Network 28:
#   Number of nodes: 3105
#   Number of edges: 1125970
#   Density: 0.23365414944303337
#   Average degree: 725.2624798711755
#   Average clustering coefficient: 0.7576242970395042
#
# Network 29:
#   Number of nodes: 3105
#   Number of edges: 1157128
#   Density: 0.24011985988678056
#   Average degree: 745.3320450885668
#   Average clustering coefficient: 0.7784756677992877
#
# Network 30:
#   Number of nodes: 3105
#   Number of edges: 945645
#   Density: 0.19623424971363115
#   Average degree: 609.1111111111111
#   Average clustering coefficient: 0.7341008922015838
#
# Network 31:
#   Number of nodes: 3105
#   Number of edges: 755894
#   Density: 0.15685832627786908
#   Average degree: 486.88824476650564
#   Average clustering coefficient: 0.6746444205303431
#
# Network 32:
#   Number of nodes: 3105
#   Number of edges: 831972
#   Density: 0.1726455500771951
#   Average degree: 535.8917874396135
#   Average clustering coefficient: 0.707307425613808
#
#
# Average values across all networks:
#   Average Density: 0.0811427219254777
#   Average Degree: 251.8670088566828
#   Average Clustering Coefficient: 0.5664025867453966

# %%
# Step 5: Visualize the parameters
plt.figure(figsize=(8, 5))

# Density
plt.plot(range(1, len(network_list) + 1), densities, marker='o', color='b')
plt.title("Network Density")
plt.xlabel("Network")
plt.ylabel("Density")
plt.grid(True)
plt.savefig('density2.png')

# Average degree
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(network_list) + 1), average_degrees, marker='o', color='g')
plt.title("Average Degree")
plt.xlabel("Network")
plt.ylabel("Average Degree")
plt.grid(True)
plt.savefig('degree2.png')

# Clustering coefficient
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(network_list) + 1), clustering_coefficients, marker='o', color='r')
plt.title("Average Clustering Coefficient")
plt.xlabel("Network")
plt.ylabel("Clustering Coefficient")
plt.grid(True)
plt.savefig('clustering2.png')

plt.tight_layout()
plt.show()
