# %%
import pandas as pd

#2020
#Upload del file CSV 
df_2020 = pd.read_csv('/Users/gianmarcoferrara/ComplexNetworksProject/filtered_2020.csv')

#Ordino per data e contea
df_2020 = df_2020.sort_values(by=['county', 'date'])

print(df_2020)

#Sottrago i casi del giorno precedente
df_2020['new_cases'] = df_2020.groupby('county')['cases'].diff().fillna(0)

df_2020['new_cases'] = df_2020['new_cases'].astype(int)

#Tolgo colonne che non interessano
df_2020 = df_2020.drop(columns=['fips'])
df_2020 = df_2020.drop(columns=['deaths'])

print(df_2020)

#New CSV file
df_2020.to_csv('/Users/gianmarcoferrara/ComplexNetworksProject/new_daily_2020')


#2021
#Upload del file CSV 
df_2021 = pd.read_csv('/Users/gianmarcoferrara/ComplexNetworksProject/filtered_2021.csv')

#Ordino per data e contea
df_2021 = df_2021.sort_values(by=['county', 'date'])

print(df_2021)

#Sottrago i casi del giorno precedente
df_2021['new_cases'] = df_2021.groupby('county')['cases'].diff().fillna(0)

df_2021['new_cases'] = df_2021['new_cases'].astype(int)

#Tolgo colonne che non interessano
df_2021 = df_2021.drop(columns=['fips'])
df_2021 = df_2021.drop(columns=['deaths'])

print(df_2021)

#New CSV file
df_2021.to_csv('/Users/gianmarcoferrara/ComplexNetworksProject/new_daily_2021')


#2022
#Upload del file CSV 
df_2022 = pd.read_csv('/Users/gianmarcoferrara/ComplexNetworksProject/filtered_2022.csv')

#Ordino per data e contea
df_2022 = df_2022.sort_values(by=['county', 'date'])

print(df_2022)

#Sottrago i casi del giorno precedente
df_2022['new_cases'] = df_2022.groupby('county')['cases'].diff().fillna(0)

df_2022['new_cases'] = df_2022['new_cases'].astype(int)

#Tolgo colonne che non interessano
df_2022 = df_2022.drop(columns=['fips'])
df_2022 = df_2022.drop(columns=['deaths'])

print(df_2022)

#New CSV file
df_2022.to_csv('/Users/gianmarcoferrara/ComplexNetworksProject/new_daily_2022')


#2023
#Upload del file CSV 
df_2023 = pd.read_csv('/Users/gianmarcoferrara/ComplexNetworksProject/filtered_2023.csv')

#Ordino per data e contea
df_2023 = df_2023.sort_values(by=['county', 'date'])

print(df_2023)

#Sottrago i casi del giorno precedente
df_2023['new_cases'] = df_2023.groupby('county')['cases'].diff().fillna(0)

df_2023['new_cases'] = df_2023['new_cases'].astype(int)

#Tolgo colonne che non interessano
df_2023 = df_2023.drop(columns=['fips'])
df_2023 = df_2023.drop(columns=['deaths'])

print(df_2023)

#New CSV file
df_2023.to_csv('/Users/gianmarcoferrara/ComplexNetworksProject/new_daily_2023')
# Out:
#               date     county           state     fips  cases  deaths
# 591     2020-03-19  Abbeville  South Carolina  45001.0      1     0.0
# 1454    2020-03-20  Abbeville  South Carolina  45001.0      1     0.0
# 2448    2020-03-21  Abbeville  South Carolina  45001.0      1     0.0
# 3558    2020-03-22  Abbeville  South Carolina  45001.0      1     0.0
# 4756    2020-03-23  Abbeville  South Carolina  45001.0      1     0.0
# ...            ...        ...             ...      ...    ...     ...
# 839297  2020-12-27    Ziebach    South Dakota  46137.0    288     7.0
# 842427  2020-12-28    Ziebach    South Dakota  46137.0    288     7.0
# 845557  2020-12-29    Ziebach    South Dakota  46137.0    289     7.0
# 848687  2020-12-30    Ziebach    South Dakota  46137.0    291     8.0
# 851817  2020-12-31    Ziebach    South Dakota  46137.0    291     8.0
#
# [852535 rows x 6 columns]
#               date     county           state  cases  new_cases
# 591     2020-03-19  Abbeville  South Carolina      1          0
# 1454    2020-03-20  Abbeville  South Carolina      1          0
# 2448    2020-03-21  Abbeville  South Carolina      1          0
# 3558    2020-03-22  Abbeville  South Carolina      1          0
# 4756    2020-03-23  Abbeville  South Carolina      1          0
# ...            ...        ...             ...    ...        ...
# 839297  2020-12-27    Ziebach    South Dakota    288          0
# 842427  2020-12-28    Ziebach    South Dakota    288          0
# 845557  2020-12-29    Ziebach    South Dakota    289          1
# 848687  2020-12-30    Ziebach    South Dakota    291          2
# 851817  2020-12-31    Ziebach    South Dakota    291          0
#
# [852535 rows x 5 columns]
#                date     county           state     fips  cases  deaths
# 2301     2021-01-01  Abbeville  South Carolina  45001.0   1275    25.0
# 5433     2021-01-02  Abbeville  South Carolina  45001.0   1282    25.0
# 8564     2021-01-03  Abbeville  South Carolina  45001.0   1294    26.0
# 11695    2021-01-04  Abbeville  South Carolina  45001.0   1301    26.0
# 14825    2021-01-05  Abbeville  South Carolina  45001.0   1305    26.0
# ...             ...        ...             ...      ...    ...     ...
# 1129984  2021-12-27    Ziebach    South Dakota  46137.0    487    11.0
# 1133117  2021-12-28    Ziebach    South Dakota  46137.0    487    11.0
# 1136251  2021-12-29    Ziebach    South Dakota  46137.0    487    11.0
# 1139385  2021-12-30    Ziebach    South Dakota  46137.0    487    11.0
# 1142520  2021-12-31    Ziebach    South Dakota  46137.0    487    11.0
#
# [1143238 rows x 6 columns]
#                date     county           state  cases  new_cases
# 2301     2021-01-01  Abbeville  South Carolina   1275          0
# 5433     2021-01-02  Abbeville  South Carolina   1282          7
# 8564     2021-01-03  Abbeville  South Carolina   1294         12
# 11695    2021-01-04  Abbeville  South Carolina   1301          7
# 14825    2021-01-05  Abbeville  South Carolina   1305          4
# ...             ...        ...             ...    ...        ...
# 1129984  2021-12-27    Ziebach    South Dakota    487          0
# 1133117  2021-12-28    Ziebach    South Dakota    487          0
# 1136251  2021-12-29    Ziebach    South Dakota    487          0
# 1139385  2021-12-30    Ziebach    South Dakota    487          0
# 1142520  2021-12-31    Ziebach    South Dakota    487          0
#
# [1143238 rows x 5 columns]
#                date     county           state     fips  cases  deaths
# 2306     2022-01-01  Abbeville  South Carolina  45001.0   4282    54.0
# 5441     2022-01-02  Abbeville  South Carolina  45001.0   4282    54.0
# 8576     2022-01-03  Abbeville  South Carolina  45001.0   4282    54.0
# 11711    2022-01-04  Abbeville  South Carolina  45001.0   4394    55.0
# 14846    2022-01-05  Abbeville  South Carolina  45001.0   4407    56.0
# ...             ...        ...             ...      ...    ...     ...
# 1132287  2022-12-27    Ziebach    South Dakota  46137.0    707    12.0
# 1135423  2022-12-28    Ziebach    South Dakota  46137.0    707    12.0
# 1138560  2022-12-29    Ziebach    South Dakota  46137.0    707    12.0
# 1141699  2022-12-30    Ziebach    South Dakota  46137.0    707    12.0
# 1144838  2022-12-31    Ziebach    South Dakota  46137.0    707    12.0
#
# [1145559 rows x 6 columns]
#                date     county           state  cases  new_cases
# 2306     2022-01-01  Abbeville  South Carolina   4282          0
# 5441     2022-01-02  Abbeville  South Carolina   4282          0
# 8576     2022-01-03  Abbeville  South Carolina   4282          0
# 11711    2022-01-04  Abbeville  South Carolina   4394        112
# 14846    2022-01-05  Abbeville  South Carolina   4407         13
# ...             ...        ...             ...    ...        ...
# 1132287  2022-12-27    Ziebach    South Dakota    707          0
# 1135423  2022-12-28    Ziebach    South Dakota    707          0
# 1138560  2022-12-29    Ziebach    South Dakota    707          0
# 1141699  2022-12-30    Ziebach    South Dakota    707          0
# 1144838  2022-12-31    Ziebach    South Dakota    707          0
#
# [1145559 rows x 5 columns]
#              date     county           state     fips  cases  deaths
# 2309   2023-02-22  Abbeville  South Carolina  45001.0   7806    95.0
# 5451   2023-02-23  Abbeville  South Carolina  45001.0   7806    95.0
# 8593   2023-02-24  Abbeville  South Carolina  45001.0   7806    95.0
# 11735  2023-02-25  Abbeville  South Carolina  45001.0   7806    95.0
# 14877  2023-02-26  Abbeville  South Carolina  45001.0   7806    95.0
# ...           ...        ...             ...      ...    ...     ...
# 80917  2023-03-19    Ziebach    South Dakota  46137.0    719    13.0
# 84057  2023-03-20    Ziebach    South Dakota  46137.0    719    13.0
# 87197  2023-03-21    Ziebach    South Dakota  46137.0    719    13.0
# 90338  2023-03-22    Ziebach    South Dakota  46137.0    720    13.0
# 93479  2023-03-23    Ziebach    South Dakota  46137.0    720    13.0
#
# [94201 rows x 6 columns]
#              date     county           state  cases  new_cases
# 2309   2023-02-22  Abbeville  South Carolina   7806          0
# 5451   2023-02-23  Abbeville  South Carolina   7806          0
# 8593   2023-02-24  Abbeville  South Carolina   7806          0
# 11735  2023-02-25  Abbeville  South Carolina   7806          0
# 14877  2023-02-26  Abbeville  South Carolina   7806          0
# ...           ...        ...             ...    ...        ...
# 80917  2023-03-19    Ziebach    South Dakota    719          0
# 84057  2023-03-20    Ziebach    South Dakota    719          0
# 87197  2023-03-21    Ziebach    South Dakota    719          0
# 90338  2023-03-22    Ziebach    South Dakota    720          1
# 93479  2023-03-23    Ziebach    South Dakota    720          0
#
# [94201 rows x 5 columns]
